# %%
import numpy as np
import matplotlib as mpl
# Display plots inline, directly below the cell that produced it.
# %matplotlib inline 
import matplotlib.pyplot as plt
import time

# Ignore warnings  
import warnings
warnings.filterwarnings("ignore",category=UserWarning)

# %%
# get holder 

holder = np.load('../data/oscillator_holder.npy')
# Plotting rasterplot
fig1 = plt.figure()
mpl.rcParams['figure.dpi'] = 90 
plt.scatter(holder[:,1]/1e3, holder[:,0], marker='|',color='k')
plt.xlabel('Time (ms)')
plt.ylabel('Neuron ID')
plt.xlim(100, 700)
plt.show()
